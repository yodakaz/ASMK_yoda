# %%
import os
os.chdir('/home/yoda/Jupyterlab_3/content')
# !git clone https://github.com/gtolias/how.git

# !git clone https://github.com/MING410/local #local
# Out:
# Cloning into 'how'...
# remote: Enumerating objects: 53, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 53 (delta 4), reused 43 (delta 2), pack-reused 0
# Unpacking objects: 100% (53/53), done.
# Cloning into 'local'...
# remote: Enumerating objects: 5839, done.
# remote: Counting objects: 100% (1934/1934), done.
# remote: Compressing objects: 100% (135/135), done.
# remote: Total 5839 (delta 1799), reused 1934 (delta 1799), pack-reused 3905
# Receiving objects: 100% (5839/5839), 468.04 MiB | 10.74 MiB/s, done.
# Resolving deltas: 100% (3689/3689), done.
# Checking out files: 100% (7539/7539), done.

# %%
import os
root_path = '/home/yoda/Jupyterlab_3'
os.chdir(root_path)
os.chdir('./content/how')
# !wget "https://github.com/filipradenovic/cnnimageretrieval-pytorch/archive/v1.2.zip"
# !unzip v1.2.zip
# !rm v1.2.zip
# !export PYTHONPATH=${PYTHONPATH}:$(realpath cnnimageretrieval-pytorch-1.2)

#"cirtorh"をhowに入れる
# Out:
# --2021-06-18 09:11:31--  https://github.com/filipradenovic/cnnimageretrieval-pytorch/archive/v1.2.zip
# github.com (github.com) をDNSに問いあわせています... 52.192.72.89
# github.com (github.com)|52.192.72.89|:443 に接続しています... 接続しました。
# HTTP による接続要求を送信しました、応答を待っています... 302 Found
# 場所: https://codeload.github.com/filipradenovic/cnnimageretrieval-pytorch/zip/v1.2 [続く]
# --2021-06-18 09:11:31--  https://codeload.github.com/filipradenovic/cnnimageretrieval-pytorch/zip/v1.2
# codeload.github.com (codeload.github.com) をDNSに問いあわせています... 13.112.159.149
# codeload.github.com (codeload.github.com)|13.112.159.149|:443 に接続しています... 接続しました。
# HTTP による接続要求を送信しました、応答を待っています... 200 OK
# 長さ: 特定できません [application/zip]
# `v1.2.zip' に保存中
#
# v1.2.zip                [  <=>               ]  41.06K   205KB/s    時間 0.2s
#
# 2021-06-18 09:11:32 (205 KB/s) - `v1.2.zip' へ保存終了 [42048]
#
# Archive:  v1.2.zip
# 7da5c2a8c7e6d27ac652d1de137d17df31cb510a
#    creating: cnnimageretrieval-pytorch-1.2/
#   inflating: cnnimageretrieval-pytorch-1.2/LICENSE
#   inflating: cnnimageretrieval-pytorch-1.2/README.md
#    creating: cnnimageretrieval-pytorch-1.2/cirtorch/
#   inflating: cnnimageretrieval-pytorch-1.2/cirtorch/__init__.py
#    creating: cnnimageretrieval-pytorch-1.2/cirtorch/datasets/
#  extracting: cnnimageretrieval-pytorch-1.2/cirtorch/datasets/__init__.py
#   inflating: cnnimageretrieval-pytorch-1.2/cirtorch/datasets/datahelpers.py
#   inflating: cnnimageretrieval-pytorch-1.2/cirtorch/datasets/genericdataset.py
#   inflating: cnnimageretrieval-pytorch-1.2/cirtorch/datasets/testdataset.py
#   inflating: cnnimageretrieval-pytorch-1.2/cirtorch/datasets/traindataset.py
#    creating: cnnimageretrieval-pytorch-1.2/cirtorch/examples/
#  extracting: cnnimageretrieval-pytorch-1.2/cirtorch/examples/__init__.py
#   inflating: cnnimageretrieval-pytorch-1.2/cirtorch/examples/example_descriptor_extraction.py
#   inflating: cnnimageretrieval-pytorch-1.2/cirtorch/examples/test.py
#   inflating: cnnimageretrieval-pytorch-1.2/cirtorch/examples/test_e2e.py
#   inflating: cnnimageretrieval-pytorch-1.2/cirtorch/examples/train.py
#    creating: cnnimageretrieval-pytorch-1.2/cirtorch/layers/
#  extracting: cnnimageretrieval-pytorch-1.2/cirtorch/layers/__init__.py
#   inflating: cnnimageretrieval-pytorch-1.2/cirtorch/layers/functional.py
#   inflating: cnnimageretrieval-pytorch-1.2/cirtorch/layers/loss.py
#   inflating: cnnimageretrieval-pytorch-1.2/cirtorch/layers/normalization.py
#   inflating: cnnimageretrieval-pytorch-1.2/cirtorch/layers/pooling.py
#    creating: cnnimageretrieval-pytorch-1.2/cirtorch/networks/
#  extracting: cnnimageretrieval-pytorch-1.2/cirtorch/networks/__init__.py
#   inflating: cnnimageretrieval-pytorch-1.2/cirtorch/networks/imageretrievalnet.py
#    creating: cnnimageretrieval-pytorch-1.2/cirtorch/utils/
#  extracting: cnnimageretrieval-pytorch-1.2/cirtorch/utils/__init__.py
#   inflating: cnnimageretrieval-pytorch-1.2/cirtorch/utils/download.py
#   inflating: cnnimageretrieval-pytorch-1.2/cirtorch/utils/download_win.py
#   inflating: cnnimageretrieval-pytorch-1.2/cirtorch/utils/evaluate.py
#   inflating: cnnimageretrieval-pytorch-1.2/cirtorch/utils/general.py
#   inflating: cnnimageretrieval-pytorch-1.2/cirtorch/utils/whiten.py

# %%
#%load_ext cython
import os
import sys
print(sys.path)
root_path = '/home/yoda/Jupyterlab_3'
os.chdir(root_path)
os.chdir('./content/how')
# asmk
#!pip3 install python3-devel
# !git clone https://github.com/jenicek/asmk.git
# !pip3 install pyaml numpy faiss-gpu
#!pip3 install torch==1.7.0 
#!pip3 install cython
# !cd asmk
# !python3 ./asmk/setup.py build_ext --inplace
# !rm -r build
# !cd ..
# !export PYTHONPATH=${PYTHONPATH}:$(realpath asmk)
#"asmk"(全体)をhowにいれる
# Out:
# ['/home/yoda', '/home/yoda/.linuxbrew/opt/python@3.9/lib/python39.zip', '/home/yoda/.linuxbrew/opt/python@3.9/lib/python3.9', '/home/yoda/.linuxbrew/opt/python@3.9/lib/python3.9/lib-dynload', '', '/home/yoda/.linuxbrew/opt/python@3.9/lib/python3.9/site-packages', '/home/yoda/.linuxbrew/opt/python@3.9/lib/python3.9/site-packages/IPython/extensions', '/home/yoda/.ipython']
# fatal: destination path 'asmk' already exists and is not an empty directory.
# Requirement already satisfied: pyaml in /home/yoda/.linuxbrew/lib/python3.7/site-packages (20.4.0)
# Requirement already satisfied: numpy in /home/yoda/.linuxbrew/lib/python3.7/site-packages (1.20.3)
# Requirement already satisfied: faiss-gpu in /home/yoda/.linuxbrew/lib/python3.7/site-packages (1.7.1.post2)
# Requirement already satisfied: PyYAML in /home/yoda/.linuxbrew/lib/python3.7/site-packages (from pyaml) (5.4.1)
# running build_ext
# building 'asmk.hamming' extension
# creating build
# creating build/temp.linux-x86_64-3.7
# creating build/temp.linux-x86_64-3.7/asmk
# creating build/temp.linux-x86_64-3.7/asmk/cython
# gcc-5 -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -O3 -Wall -fPIC -I/home/yoda/.linuxbrew/include -I/home/yoda/.linuxbrew/opt/openssl@1.1/include -I/home/yoda/.linuxbrew/opt/sqlite/include -I/home/yoda/.linuxbrew/opt/python@3.7/include/python3.7m -c asmk/cython/hamming.c -o build/temp.linux-x86_64-3.7/asmk/cython/hamming.o
# creating build/lib.linux-x86_64-3.7
# creating build/lib.linux-x86_64-3.7/asmk
# gcc-5 -pthread -shared -L/home/yoda/.linuxbrew/lib build/temp.linux-x86_64-3.7/asmk/cython/hamming.o -L/home/yoda/.linuxbrew/lib -L/home/yoda/.linuxbrew/opt/openssl@1.1/lib -L/home/yoda/.linuxbrew/opt/sqlite/lib -L/home/yoda/.linuxbrew/opt/python@3.7/lib -lpython3.7m -o build/lib.linux-x86_64-3.7/asmk/hamming.cpython-37m-x86_64-linux-gnu.so
# copying build/lib.linux-x86_64-3.7/asmk/hamming.cpython-37m-x86_64-linux-gnu.so -> asmk

# %%
#!python3.9
# !which python3
#!ln -s /usr/bin/python3 /home/yoda/.linuxbrew/opt/python@3.9/bin/python3.9
import sys
print(sys.path)
print(sys.version)
print(sys.executable)
# !pip3 install Cython
# Out:
# /usr/bin/python3
# ['/home/yoda', '/home/yoda/.linuxbrew/opt/python@3.9/lib/python39.zip', '/home/yoda/.linuxbrew/opt/python@3.9/lib/python3.9', '/home/yoda/.linuxbrew/opt/python@3.9/lib/python3.9/lib-dynload', '', '/home/yoda/.linuxbrew/opt/python@3.9/lib/python3.9/site-packages', '/home/yoda/.linuxbrew/opt/python@3.9/lib/python3.9/site-packages/IPython/extensions', '/home/yoda/.ipython']
# 3.9.5 (default, May  3 2021, 15:11:33)
# [GCC 5.5.0 20171010]
# /home/yoda/.linuxbrew/opt/python@3.9/bin/python3.9
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: Cython in /home/yoda/.local/lib/python3.6/site-packages (0.29.23)

# %%
import os
root_path = '/home/yoda/Jupyterlab_2'
os.chdir(root_path)
os.chdir('./content/how')

# !pip3 install -r requirements.txt
# Out:
# Requirement already satisfied: numpy in /home/yoda/.linuxbrew/lib/python3.7/site-packages (from -r requirements.txt (line 1)) (1.20.3)
# Requirement already satisfied: pyaml in /home/yoda/.linuxbrew/lib/python3.7/site-packages (from -r requirements.txt (line 2)) (20.4.0)
# Requirement already satisfied: matplotlib in /home/yoda/.linuxbrew/lib/python3.7/site-packages (from -r requirements.txt (line 3)) (3.4.2)
# Collecting torch==1.3.1
#   Using cached torch-1.3.1-cp37-cp37m-manylinux1_x86_64.whl (734.6 MB)
# Collecting torchvision==0.4.2
#   Using cached torchvision-0.4.2-cp37-cp37m-manylinux1_x86_64.whl (10.2 MB)
# Requirement already satisfied: pillow>=4.1.1 in /home/yoda/.linuxbrew/lib/python3.7/site-packages (from torchvision==0.4.2->-r requirements.txt (line 5)) (8.2.0)
# Requirement already satisfied: six in /home/yoda/.linuxbrew/lib/python3.7/site-packages (from torchvision==0.4.2->-r requirements.txt (line 5)) (1.16.0)
# Requirement already satisfied: cycler>=0.10 in /home/yoda/.linuxbrew/lib/python3.7/site-packages (from matplotlib->-r requirements.txt (line 3)) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/yoda/.linuxbrew/lib/python3.7/site-packages (from matplotlib->-r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/yoda/.linuxbrew/lib/python3.7/site-packages (from matplotlib->-r requirements.txt (line 3)) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/yoda/.linuxbrew/lib/python3.7/site-packages (from matplotlib->-r requirements.txt (line 3)) (2.8.1)
# Requirement already satisfied: PyYAML in /home/yoda/.linuxbrew/lib/python3.7/site-packages (from pyaml->-r requirements.txt (line 2)) (5.4.1)
# Installing collected packages: torch, torchvision
#   Attempting uninstall: torch
#     Found existing installation: torch 1.9.0+cu111
#     Uninstalling torch-1.9.0+cu111:
#       Successfully uninstalled torch-1.9.0+cu111
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.10.0+cu111
#     Uninstalling torchvision-0.10.0+cu111:
#       Successfully uninstalled torchvision-0.10.0+cu111
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 0.9.0 requires torch==1.9.0, but you have torch 1.3.1 which is incompatible.
# Successfully installed torch-1.3.1 torchvision-0.4.2

# %%
# !wget https://anaconda.org/pytorch/faiss-gpu/1.7.0/download/linux-64/faiss-gpu-1.7.0-py3.7_h080d439_113_cuda10.2.tar.bz2
# !tar xvjf faiss-gpu-1.7.0-py3.7_h080d439_113_cuda10.2.tar.bz2
#import faiss
# Out:
# --2021-06-22 11:49:15--  https://anaconda.org/pytorch/faiss-gpu/1.7.0/download/linux-64/faiss-gpu-1.7.0-py3.7_h080d439_113_cuda10.2.tar.bz2
# anaconda.org (anaconda.org) をDNSに問いあわせています... 104.17.92.24, 104.17.93.24, 2606:4700::6811:5d18, ...
# anaconda.org (anaconda.org)|104.17.92.24|:443 に接続しています... 接続しました。
# HTTP による接続要求を送信しました、応答を待っています... 302 FOUND
# 場所: https://binstar-cio-packages-prod.s3.amazonaws.com/5a15c9cc393ec612061f033a/60b056ac5f0624224ad09a00?response-content-disposition=attachment%3B%20filename%3D%22faiss-gpu-1.7.0-py3.7_h080d439_113_cuda10.2.tar.bz2%22%3B%20filename%2A%3DUTF-8%27%27faiss-gpu-1.7.0-py3.7_h080d439_113_cuda10.2.tar.bz2&response-content-type=application%2Fx-tar&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Expires=60&X-Amz-Date=20210622T024916Z&X-Amz-SignedHeaders=host&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEAEaCXVzLWVhc3QtMSJGMEQCICmeAQSgHuV1kezteijhQX%2FXbhYNrPIbuwLW%2BF616vqbAiAS174LoPECT8%2FIsjysHQh404zYUrXxaGFotQwzPZvsjiqDBAjK%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDQ1NTg2NDA5ODM3OCIMbEoSLdRoS7bps41DKtcDzqxHeeX7gc9AwExIV7pnByBY1b35REm%2Fb9yXFlV4KuXVfppJ3iXv1lObO4oZkcLT61O2j9DuXWqkx06ykgVQ5M6BUujENH4VEE3cbTTyUvRA%2FcpK88M3YdlFckXexsucMBD%2F%2BprMkTXjABJ6Yxnkum%2F9WNf3sj5QVmfkpzx2zlTkcCEpp66i%2FOQ5slIHZaC3CgJ0rGOkVNBdffK49XVLuxR1Rngt4ArwUp5ATEY6zlg1nxG5irNKXnXh0d0XZmlvqJ6PHoCUtZoPozV4E4AdXbay4Blgalb6JDW8mPQuVhtuMb14sGz3%2BwPHZ9oav%2BvePTg1j9fGGl8OghNhMg5LuJV6pTb%2FjkvtTnu%2FiEMeQvLwGfGK1Su8oagOfal8FrCVdzX1kBkMH3GNIp%2Bn%2FLPS3NmVuyQ8q0niUx%2FF5Iq2%2Fh3gaB%2Bce03pmQ1V4MckXpFJtMBQer%2FjB5vp7efSRYWwozGa4bLCLgSWxp4vYYOCIvpl7cFwrevKag%2F9nb3tfXhekDkhF0wX4RDD3Uy%2FUOxKqj6mLtGfUAReBHt7Sk79afTqZExqSV0OAYMFcF0dCxE0R84IvxD9z7uvpWNaHvWkoY%2BUYveXPFbMMTqp55xY5si1oGo%2FQm2bMIHrxIYGOqYBFdmk3Rp30CivsrTBdpO0dtvJgHzaBqQJ3Ja4tMbmQvwNwdqoVW6%2FOBdTTXIY65gCPURjlHuR5gUPQdkxvg1kyyVUGBcrjIwKEznIntHluYH%2B3wGYcltzsjCX8pqqWwAdzRTtsmW2DYM8UQtaU%2F6frYzAY3MlQ4ZXUxvH6ATxAC7xUPVmW8N1UQn%2FqZhCSY3x4kwBPWrrtqUPJP0uEPn4PlJKS010Bw%3D%3D&X-Amz-Credential=ASIAWUI46DZFM2NK4EIF%2F20210622%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=5c15d694f2c2fffe0e7276d37064fa8fc5c6e251b9a97a114be914b521f8fbea [続く]
# --2021-06-22 11:49:16--  https://binstar-cio-packages-prod.s3.amazonaws.com/5a15c9cc393ec612061f033a/60b056ac5f0624224ad09a00?response-content-disposition=attachment%3B%20filename%3D%22faiss-gpu-1.7.0-py3.7_h080d439_113_cuda10.2.tar.bz2%22%3B%20filename%2A%3DUTF-8%27%27faiss-gpu-1.7.0-py3.7_h080d439_113_cuda10.2.tar.bz2&response-content-type=application%2Fx-tar&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Expires=60&X-Amz-Date=20210622T024916Z&X-Amz-SignedHeaders=host&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEAEaCXVzLWVhc3QtMSJGMEQCICmeAQSgHuV1kezteijhQX%2FXbhYNrPIbuwLW%2BF616vqbAiAS174LoPECT8%2FIsjysHQh404zYUrXxaGFotQwzPZvsjiqDBAjK%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDQ1NTg2NDA5ODM3OCIMbEoSLdRoS7bps41DKtcDzqxHeeX7gc9AwExIV7pnByBY1b35REm%2Fb9yXFlV4KuXVfppJ3iXv1lObO4oZkcLT61O2j9DuXWqkx06ykgVQ5M6BUujENH4VEE3cbTTyUvRA%2FcpK88M3YdlFckXexsucMBD%2F%2BprMkTXjABJ6Yxnkum%2F9WNf3sj5QVmfkpzx2zlTkcCEpp66i%2FOQ5slIHZaC3CgJ0rGOkVNBdffK49XVLuxR1Rngt4ArwUp5ATEY6zlg1nxG5irNKXnXh0d0XZmlvqJ6PHoCUtZoPozV4E4AdXbay4Blgalb6JDW8mPQuVhtuMb14sGz3%2BwPHZ9oav%2BvePTg1j9fGGl8OghNhMg5LuJV6pTb%2FjkvtTnu%2FiEMeQvLwGfGK1Su8oagOfal8FrCVdzX1kBkMH3GNIp%2Bn%2FLPS3NmVuyQ8q0niUx%2FF5Iq2%2Fh3gaB%2Bce03pmQ1V4MckXpFJtMBQer%2FjB5vp7efSRYWwozGa4bLCLgSWxp4vYYOCIvpl7cFwrevKag%2F9nb3tfXhekDkhF0wX4RDD3Uy%2FUOxKqj6mLtGfUAReBHt7Sk79afTqZExqSV0OAYMFcF0dCxE0R84IvxD9z7uvpWNaHvWkoY%2BUYveXPFbMMTqp55xY5si1oGo%2FQm2bMIHrxIYGOqYBFdmk3Rp30CivsrTBdpO0dtvJgHzaBqQJ3Ja4tMbmQvwNwdqoVW6%2FOBdTTXIY65gCPURjlHuR5gUPQdkxvg1kyyVUGBcrjIwKEznIntHluYH%2B3wGYcltzsjCX8pqqWwAdzRTtsmW2DYM8UQtaU%2F6frYzAY3MlQ4ZXUxvH6ATxAC7xUPVmW8N1UQn%2FqZhCSY3x4kwBPWrrtqUPJP0uEPn4PlJKS010Bw%3D%3D&X-Amz-Credential=ASIAWUI46DZFM2NK4EIF%2F20210622%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=5c15d694f2c2fffe0e7276d37064fa8fc5c6e251b9a97a114be914b521f8fbea
# binstar-cio-packages-prod.s3.amazonaws.com (binstar-cio-packages-prod.s3.amazonaws.com) をDNSに問いあわせています... 52.216.1.144
# binstar-cio-packages-prod.s3.amazonaws.com (binstar-cio-packages-prod.s3.amazonaws.com)|52.216.1.144|:443 に接続しています... 接続しました。
# HTTP による接続要求を送信しました、応答を待っています... 200 OK
# 長さ: 2093261 (2.0M) [application/x-tar]
# `faiss-gpu-1.7.0-py3.7_h080d439_113_cuda10.2.tar.bz2' に保存中
#
# faiss-gpu-1.7.0-py3 100%[===================>]   2.00M  1.01MB/s    時間 2.0s
#
# 2021-06-22 11:49:19 (1.01 MB/s) - `faiss-gpu-1.7.0-py3.7_h080d439_113_cuda10.2.tar.bz2' へ保存完了 [2093261/2093261]
#
# info/hash_input.json
# info/index.json
# info/git
# info/files
# info/about.json
# info/paths.json
# lib/python3.7/site-packages/faiss-1.7.1-py3.7.egg-info/PKG-INFO
# info/test/tests/test_omp_threads.cpp
# info/test/tests/test_binary_flat.cpp
# info/test/tests/test_ivfpq_codec.cpp
# info/test/tests/test_ivfpq_indexing.cpp
# info/test/tests/test_pq_encoding.cpp
# info/test/faiss/gpu/test/TestGpuMemoryException.cpp
# info/test/faiss/gpu/test/TestGpuIndexBinaryFlat.cpp
# info/test/faiss/gpu/test/demo_ivfpq_indexing_gpu.cpp
# info/test/tests/test_transfer_invlists.cpp
# info/test/tests/test_dealloc_invlists.cpp
# info/test/tests/test_pairs_decoding.cpp
# info/test/tests/test_ondisk_ivf.cpp
# info/test/tests/test_params_override.cpp
# info/test/tests/test_sliding_ivf.cpp
# info/test/tests/test_threaded_index.cpp
# info/test/faiss/gpu/test/TestGpuIndexIVFScalarQuantizer.cpp
# info/test/tests/test_merge.cpp
# info/test/faiss/gpu/test/TestUtils.cpp
# info/test/faiss/gpu/test/TestGpuIndexFlat.cpp
# info/test/faiss/gpu/test/TestCodePacking.cpp
# info/test/faiss/gpu/test/TestGpuIndexIVFFlat.cpp
# info/test/tests/test_lowlevel_ivf.cpp
# info/test/faiss/gpu/test/TestGpuIndexIVFPQ.cpp
# lib/python3.7/site-packages/faiss/_swigfaiss.so
# lib/python3.7/site-packages/faiss/_swigfaiss_avx2.so
# info/test/tests/test_omp_threads_py.py
# info/test/tests/test_documentation.py
# lib/python3.7/site-packages/faiss/contrib/vecs_io.py
# info/test/tests/test_oom_exception.py
# info/test/tests/test_binary_factory.py
# info/test/tests/test_refine.py
# info/test/tests/test_autotune.py
# info/test/faiss/gpu/test/test_contrib.py
# lib/python3.7/site-packages/faiss/contrib/ondisk.py
# lib/python3.7/site-packages/faiss/contrib/inspect_tools.py
# lib/python3.7/site-packages/faiss/loader.py
# lib/python3.7/site-packages/faiss/contrib/ivf_tools.py
# lib/python3.7/site-packages/faiss/contrib/client_server.py
# info/test/tests/test_referenced_objects.py
# lib/python3.7/site-packages/faiss/contrib/factory_tools.py
# info/test/tests/common_faiss_tests.py
# info/test/tests/test_extra_distances.py
# info/test/tests/test_product_quantizer.py
# info/test/tests/test_binary_io.py
# info/test/tests/test_index_binary_from_float.py
# info/test/tests/test_ivflib.py
# info/test/tests/test_factory.py
# info/test/tests/test_binary_hashindex.py
# info/test/faiss/gpu/test/test_gpu_index_ivfsq.py
# lib/python3.7/site-packages/faiss/contrib/rpc.py
# lib/python3.7/site-packages/faiss/contrib/evaluation.py
# info/test/tests/test_meta_index.py
# info/test/tests/test_io.py
# info/test/tests/test_clustering.py
# lib/python3.7/site-packages/faiss/contrib/exhaustive_search.py
# info/test/tests/test_standalone_codec.py
# info/test/tests/test_lsq.py
# lib/python3.7/site-packages/faiss/contrib/datasets.py
# info/test/tests/test_partition.py
# info/test/tests/test_contrib.py
# info/test/tests/torch_test_contrib.py
# info/test/tests/test_index_binary.py
# info/test/tests/test_fast_scan.py
# info/test/faiss/gpu/test/test_gpu_basics.py
# info/test/tests/test_residual_quantizer.py
# info/test/tests/test_build_blocks.py
# info/test/faiss/gpu/test/test_gpu_index.py
# info/test/tests/test_fast_scan_ivf.py
# info/test/faiss/gpu/test/torch_test_contrib_gpu.py
# info/test/tests/test_index_composite.py
# lib/python3.7/site-packages/faiss/contrib/torch_utils.py
# info/test/tests/test_index_accuracy.py
# info/test/tests/test_index.py
# lib/python3.7/site-packages/faiss/__init__.py
# lib/python3.7/site-packages/faiss/swigfaiss.py
# lib/python3.7/site-packages/faiss/swigfaiss_avx2.py
# lib/python3.7/site-packages/faiss-1.7.1-py3.7.egg-info/dependency_links.txt
# lib/python3.7/site-packages/faiss-1.7.1-py3.7.egg-info/requires.txt
# lib/python3.7/site-packages/faiss-1.7.1-py3.7.egg-info/top_level.txt
# lib/python3.7/site-packages/faiss-1.7.1-py3.7.egg-info/SOURCES.txt
# info/test/faiss/gpu/test/CMakeLists.txt
# info/test/tests/CMakeLists.txt
# info/test/test_time_dependencies.json
# info/test/run_test.sh
# info/recipe/parent/install-cmake.sh
# info/test/test_cpu_dispatch.sh
# info/recipe/parent/test_cpu_dispatch.sh
# info/recipe/parent/build-lib.sh
# info/recipe/parent/build-pkg.sh
# info/recipe/build-pkg.sh
# info/licenses/LICENSE
# info/test/faiss/gpu/test/TestUtils.h
# info/recipe/conda_build_config.yaml
# info/recipe/parent/meta.yaml
# info/recipe/meta.yaml
# lib/python3.7/site-packages/faiss/contrib/__pycache__/ondisk.cpython-37.pyc
# lib/python3.7/site-packages/faiss/contrib/__pycache__/vecs_io.cpython-37.pyc
# lib/python3.7/site-packages/faiss/contrib/__pycache__/ivf_tools.cpython-37.pyc
# lib/python3.7/site-packages/faiss/__pycache__/loader.cpython-37.pyc
# lib/python3.7/site-packages/faiss/contrib/__pycache__/factory_tools.cpython-37.pyc
# lib/python3.7/site-packages/faiss/contrib/__pycache__/inspect_tools.cpython-37.pyc
# lib/python3.7/site-packages/faiss/contrib/__pycache__/client_server.cpython-37.pyc
# lib/python3.7/site-packages/faiss/contrib/__pycache__/evaluation.cpython-37.pyc
# lib/python3.7/site-packages/faiss/contrib/__pycache__/rpc.cpython-37.pyc
# lib/python3.7/site-packages/faiss/contrib/__pycache__/exhaustive_search.cpython-37.pyc
# lib/python3.7/site-packages/faiss/contrib/__pycache__/datasets.cpython-37.pyc
# lib/python3.7/site-packages/faiss/contrib/__pycache__/torch_utils.cpython-37.pyc
# lib/python3.7/site-packages/faiss/__pycache__/__init__.cpython-37.pyc
# lib/python3.7/site-packages/faiss/__pycache__/swigfaiss.cpython-37.pyc
# lib/python3.7/site-packages/faiss/__pycache__/swigfaiss_avx2.cpython-37.pyc
# info/test/faiss/gpu/test/TestGpuDistance.cu
# info/test/faiss/gpu/test/TestGpuSelect.cu

# %%
# !pip3 uninstall faiss
import faiss
# Out:
# Found existing installation: faiss 1.5.3
# Uninstalling faiss-1.5.3:
#   Would remove:
#     /home/yoda/.linuxbrew/lib/python3.7/site-packages/faiss-1.5.3.dist-info/*
#     /home/yoda/.linuxbrew/lib/python3.7/site-packages/faiss/*
#   Would not remove (might be manually added):
#     /home/yoda/.linuxbrew/lib/python3.7/site-packages/faiss/_swigfaiss.cpython-37m-x86_64-linux-gnu.so
#     /home/yoda/.linuxbrew/lib/python3.7/site-packages/faiss/contrib/__init__.py
#     /home/yoda/.linuxbrew/lib/python3.7/site-packages/faiss/contrib/client_server.py
#     /home/yoda/.linuxbrew/lib/python3.7/site-packages/faiss/contrib/datasets.py
#     /home/yoda/.linuxbrew/lib/python3.7/site-packages/faiss/contrib/evaluation.py
#     /home/yoda/.linuxbrew/lib/python3.7/site-packages/faiss/contrib/exhaustive_search.py
#     /home/yoda/.linuxbrew/lib/python3.7/site-packages/faiss/contrib/factory_tools.py
#     /home/yoda/.linuxbrew/lib/python3.7/site-packages/faiss/contrib/inspect_tools.py
#     /home/yoda/.linuxbrew/lib/python3.7/site-packages/faiss/contrib/ivf_tools.py
#     /home/yoda/.linuxbrew/lib/python3.7/site-packages/faiss/contrib/ondisk.py
#     /home/yoda/.linuxbrew/lib/python3.7/site-packages/faiss/contrib/rpc.py
#     /home/yoda/.linuxbrew/lib/python3.7/site-packages/faiss/contrib/torch_utils.py
#     /home/yoda/.linuxbrew/lib/python3.7/site-packages/faiss/contrib/vecs_io.py
#     /home/yoda/.linuxbrew/lib/python3.7/site-packages/faiss/loader.py
#     /home/yoda/.linuxbrew/lib/python3.7/site-packages/faiss/python_callbacks.h
#     /home/yoda/.linuxbrew/lib/python3.7/site-packages/faiss/setup.py
#     /home/yoda/.linuxbrew/lib/python3.7/site-packages/faiss/swigfaiss.i
# Proceed (y/n)? ^C
# ERROR: Operation cancelled by user

# %%
#コードの実行
import os
root_path = '/home/yoda/Jupyterlab_3'
os.chdir(root_path)
os.chdir('./content/how')



#./stage/evaluate.py:asmk.asmk_method→asmk.asmk.asmk_method
#./asmk/kernel.py:import . →import ..cython
#./examples/demo_how.py:(L90)コメントアウト(自前データセット使用のため)
#./how/utils/data_helper.py:(L14～)training_set = 'mitsubishi_dataset'
#                           ims_root:'ims' → 'png_images'
#                           db = pickle.load(f)#['train'] ← コメントアウト
#./cirtorch/datasets/datahelper.py:return os.path.join()変更
#./cirtorch/datasets/traindataset.py:(L50～).ymlから読み込んだ情報修正
#if name == 'retrieval-SfM-120k':
#  print("changed retrieval-SfM-120k => mitsubishi_dataset")
#  name = 'mitsubishi_dataset'
#ims_rootの'ims' → 'png_images'
#db = pickle.load(f)#[mode] ←コメントアウト


#!python3 examples/demo_how.py eval examples/params/eccv20/eval_how_r18_1000.yml -e official_how_r18_1000
# !python3 examples/demo_how.py train examples/params/eccv20/train_how_r18.yml -e train_how_r18
#!python3 examples/demo_how.py eval examples/params/eccv20/train_how_r18_1000.yml -ml train_how_r18
# Out:
# !!!!!checkpoint__2-2-1__!!!!
# HOW INFO: Initializing network whitening
# /home/yoda/.linuxbrew/opt/python@3.7/lib/python3.7/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# >>>> 1885/1885 done...
# changed retrieval-SfM-120k => mitsubishi_dataset
# #######check loaded content######
# scores :  {'global_descriptor': defaultdict(<class 'list'>, {}), 'local_descriptor': defaultdict(<class 'list'>, {}), 'train_loss': [(1, 0.222818398039788), (2, 0.10378619345836342), (3, 0.06189663992577698), (4, 0.04006348572089337), (5, 0.021295666891150176), (6, 0.013496961122844368), (7, 0.00987832142226398), (8, 0.007607022781623528), (9, 0.006161538298561936), (10, 0.004728799684060505), (11, 0.003980073045298923), (12, 0.003172640458898968), (13, 0.0028241200090560596), (14, 0.0023239940144267166), (15, 0.0019118975398741895), (16, 0.0016369154750573217), (17, 0.0015146504850126804), (18, 0.0013062166194722522), (19, 0.001370452634364483)]}
# net_params :  {'architecture': 'resnet18', 'pretrained': True, 'skip_layer': 0, 'dim_reduction': {'dim': 128}, 'smoothing': {'kernel_size': 3}, 'runtime': {'mean_std': [[0.485, 0.456, 0.406], [0.229, 0.224, 0.225]], 'image_size': 1024, 'features_num': 1000, 'scales': [2.0, 1.414, 1.0, 0.707, 0.5, 0.353, 0.25], 'training_scales': [1]}}
# losslogger :  0.001370452634364483
# ######loaded at 20#######
# >> Creating tuples for an epoch of mitsubishi_dataset-train...
# >>>> used network:
# HOWNet(meta={
#     architecture: resnet18
#     backbone_dim: 512
#     outputdim: 128
#     corercf_size: 32
# })
# >> Extracting descriptors for query images...
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# >>>> 2000/2000 done...
# >> Extracting descriptors for negative pool...
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# >>>> 1885/1885 done...
# >> Searching for hard negatives...
# >>>> Average negative l2-distance: 0.84
# >>>> Done
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# /home/yoda/.linuxbrew/opt/python@3.7/lib/python3.7/site-packages/torch/_tensor.py:579: UserWarning: floor_divide is deprecated, and will be removed in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values.
# To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor'). (Triggered internally at  /pytorch/aten/src/ATen/native/BinaryOps.cpp:467.)
#   return torch.floor_divide(other, self)
# HOW INFO: >> Train: [20][1/400]	Time 3.927 (3.927)	Data 3.152 (3.152)	Loss 0.0006 (0.0008)
# HOW INFO: >> Train: [20][20/400]	Time 0.549 (0.790)	Data 0.000 (0.218)	Loss 0.0012 (0.0013)
# HOW INFO: >> Train: [20][40/400]	Time 0.602 (0.687)	Data 0.000 (0.109)	Loss 0.0012 (0.0016)
# HOW INFO: >> Train: [20][60/400]	Time 0.609 (0.650)	Data 0.000 (0.073)	Loss 0.0017 (0.0015)
# HOW INFO: >> Train: [20][80/400]	Time 0.612 (0.631)	Data 0.000 (0.055)	Loss 0.0007 (0.0015)
# HOW INFO: >> Train: [20][100/400]	Time 0.537 (0.617)	Data 0.000 (0.044)	Loss 0.0013 (0.0015)
# HOW INFO: >> Train: [20][120/400]	Time 0.584 (0.608)	Data 0.000 (0.037)	Loss 0.0027 (0.0014)
# HOW INFO: >> Train: [20][140/400]	Time 0.628 (0.601)	Data 0.000 (0.031)	Loss 0.0007 (0.0013)
# HOW INFO: >> Train: [20][160/400]	Time 0.580 (0.598)	Data 0.000 (0.027)	Loss 0.0002 (0.0013)
# HOW INFO: >> Train: [20][180/400]	Time 0.609 (0.594)	Data 0.000 (0.024)	Loss 0.0013 (0.0013)
# HOW INFO: >> Train: [20][200/400]	Time 0.532 (0.591)	Data 0.000 (0.022)	Loss 0.0009 (0.0012)
# HOW INFO: >> Train: [20][220/400]	Time 0.585 (0.588)	Data 0.000 (0.020)	Loss 0.0014 (0.0012)
# HOW INFO: >> Train: [20][240/400]	Time 0.563 (0.587)	Data 0.000 (0.018)	Loss 0.0009 (0.0012)
# HOW INFO: >> Train: [20][260/400]	Time 0.575 (0.585)	Data 0.000 (0.017)	Loss 0.0009 (0.0012)
# HOW INFO: >> Train: [20][280/400]	Time 0.570 (0.584)	Data 0.001 (0.016)	Loss 0.0004 (0.0012)
# HOW INFO: >> Train: [20][300/400]	Time 0.538 (0.582)	Data 0.000 (0.015)	Loss 0.0010 (0.0011)
# HOW INFO: >> Train: [20][320/400]	Time 0.564 (0.581)	Data 0.001 (0.014)	Loss 0.0009 (0.0011)
# HOW INFO: >> Train: [20][340/400]	Time 0.585 (0.580)	Data 0.000 (0.013)	Loss 0.0010 (0.0011)
# HOW INFO: >> Train: [20][360/400]	Time 0.587 (0.580)	Data 0.000 (0.012)	Loss 0.0006 (0.0011)
# HOW INFO: >> Train: [20][380/400]	Time 0.568 (0.579)	Data 0.000 (0.012)	Loss 0.0007 (0.0011)
# HOW INFO: >> Train: [20][400/400]	Time 0.476 (0.576)	Data 0.000 (0.011)	Loss 0.0005 (0.0011)
# !! show frequency !! None
# !! change frequency==22 !!
# !! show frequency !! 5
# !! change frequency==22 !!
# #######check saved content######
# scores :  {'global_descriptor': defaultdict(<class 'list'>, {}), 'local_descriptor': defaultdict(<class 'list'>, {}), 'train_loss': [(1, 0.222818398039788), (2, 0.10378619345836342), (3, 0.06189663992577698), (4, 0.04006348572089337), (5, 0.021295666891150176), (6, 0.013496961122844368), (7, 0.00987832142226398), (8, 0.007607022781623528), (9, 0.006161538298561936), (10, 0.004728799684060505), (11, 0.003980073045298923), (12, 0.003172640458898968), (13, 0.0028241200090560596), (14, 0.0023239940144267166), (15, 0.0019118975398741895), (16, 0.0016369154750573217), (17, 0.0015146504850126804), (18, 0.0013062166194722522), (19, 0.001370452634364483), (20, 0.0010906045551018907)]}
# net_params :  {'architecture': 'resnet18', 'pretrained': True, 'skip_layer': 0, 'dim_reduction': {'dim': 128}, 'smoothing': {'kernel_size': 3}, 'runtime': {'mean_std': [[0.485, 0.456, 0.406], [0.229, 0.224, 0.225]], 'image_size': 1024, 'features_num': 1000, 'scales': [2.0, 1.414, 1.0, 0.707, 0.5, 0.353, 0.25], 'training_scales': [1]}}
# losslogger :  0.0010906045551018907
# scheduler :  <torch.optim.lr_scheduler.ExponentialLR object at 0x7fd4569e1a50>
# ######saved after 20#######
# HOW INFO: Epoch 20 finished in 292.6s

# %%
# !pip3 list
# Out:
# Package            Version
# ------------------ ------------
# cycler             0.10.0
# dataclasses        0.6
# faiss-gpu          1.7.1.post2
# future             0.18.2
# importlib-metadata 3.4.0
# kiwisolver         1.3.1
# matplotlib         3.4.2
# numpy              1.20.3
# Pillow             8.2.0
# pip                21.0.1
# pyaml              20.4.0
# pyparsing          2.4.7
# python-dateutil    2.8.1
# PyYAML             5.4.1
# setuptools         53.0.0
# six                1.16.0
# torch              1.9.0+cu111
# torchaudio         0.9.0
# torchvision        0.10.0+cu111
# typing-extensions  3.10.0.0
# wheel              0.34.2
# zipp               3.4.0

# %%
import faiss
res = faiss.StandardGpuResources()
print(res)
# Out:
# <faiss.swigfaiss.StandardGpuResources; proxy of <Swig Object of type 'faiss::gpu::StandardGpuResources *' at 0x7fdb588d5270> >

# %%
<faiss.swigfaiss.StandardGpuResources; proxy of <Swig Object of type 'faiss::gpu::StandardGpuResources *' at 0x7fc06c167240> >
